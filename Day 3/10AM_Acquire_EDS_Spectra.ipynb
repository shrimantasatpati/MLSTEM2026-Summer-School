# %% [markdown]
# <font size = "5"> **Day 3: [Spectroscopic Data & ML‑Enabled Analysis](../MLSTEM2026.ipynb)** </font>
#
#
# <hr style="height:1px;border-top:4px solid #FF8200" />
#
#
#
# [Download](https://github.com/gduscher/MLSTEM2026/raw/refs/heads/main/Day3/10AM_Acquire_EDS_Spectra.ipynb)
#
# [![OpenInColab](https://colab.research.google.com/assets/colab-badge.svg)](
#    https://colab.research.google.com/github/gduscher/MLSTEM2026/blob/main/Day3/10AM_Acquire_EDS_Spectra.ipynb)
#
#
# # Acquire Image and EDS Point Spectra
#
# part of the workshop of
#
# <font size = "5"> **[Machine Learning in Transmission Electron Microscopy](../MLSTEM2026.ipynb)**</font>
#
#
# **Day3: Spectroscopic Data & ML‑Enabled Analysis**
# <table style="margin-right:auto;margin-left:0px">
#   <tr>
#     <td>Gerd Duscher </td>
#     <td>Sergei Kalinin</td>
#   </tr>
#   <tr>
#     <td colspan="2"><center>Microscopy Facilities</td>
#   </tr>
#
#   <tr>
#     <td colspan="2"><center>Materials Science & Engineering</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td colspan="2"><center>Institute of Advanced Materials & Manufacturing</td>
#   </tr>
#   <tr>
#     <td colspan="2"><center> The University of Tennessee, Knoxville</center> </td>
#   </tr>
# </table>
#
# **June 2026**
#
# Main Contributer to Notebook: Levi Dunn, Dominick Patela, Austin Houston
#
#
# ## Overview
# Acquire an image and collect EDS spectra at selected beam positions.
#
# ## Import packages for figures and
# First we load the code to make figures from pyTEMlib
# ### Check Installed Packages

# %% [markdown]
# ### Run the servers
#
# Make sure you are on the VPN and the pyTango server is running on the microscope.
#
# ```bash
# uv run startup_scripts/run_servers.py
# ```

# %% [markdown]
# ### Imports

# %%
# %matplotlib widget
import os
import json

import matplotlib.pylab as plt
import numpy  as np

import tango
import tiled.client
import pyTEMlib

print('pyTEMlib version: ', pyTEMlib.__version__)
# Out:
# pyTEMlib version:  0.2026.6.0

# %% [markdown]
# ### Ping servers

# %%
DB_HOST = "10.46.217.241"
DB_PORT = 9094

os.environ["TANGO_HOST"] = f"{DB_HOST}:{DB_PORT}"

server_names = ['stage', 'scan', 'eds', 'camera', 'data', 'microscope']

scan = tango.DeviceProxy("asyncroscopy/scan/default")
microscope = tango.DeviceProxy("asyncroscopy/instrument/default")
data = tango.DeviceProxy("asyncroscopy/data/default")

for proxy in [scan, microscope, data]:
    proxy.set_timeout_millis(120_000)
    proxy.ping()
    print(proxy.name(), proxy.state())
# Out:
# asyncroscopy/scan/default ON
# asyncroscopy/instrument/default ON
# asyncroscopy/data/default ON

# %% [markdown]
# ### Set Tiled Client

# %%
config = json.loads(data.get_config())

client = tiled.client.from_uri(config.get("uri"))
print("Tiled keys:", list(client))
config
# Out:
# Tiled keys: ['stem_image_HAADF_20260622T121457297262.h5', 'stem_image_HAADF_20260622T121515131209.h5', 'stem_image_HAADF_20260622T121718608283.h5', 'stem_image_HAADF_20260622T121811768290.h5', 'stem_image_HAADF_20260622T121846878419.h5', 'stem_image_HAADF_20260622T121906094013.h5', 'camera_image_BM-Ceta_20260622T122129622171.h5', 'stem_image_HAADF_20260622T122306394589.h5', 'stem_image_HAADF_20260622T122404037925.h5', 'stem_image_HAADF_20260622T122445781894.h5', 'stem_image_HAADF_20260622T122520552789.h5', 'stem_image_HAADF_20260622T122703330914.h5', 'stem_image_HAADF_20260622T122946694474.h5', 'stem_image_HAADF_20260622T123656869673.h5', 'camera_image_BM-Ceta_20260622T130915973468.h5', 'camera_image_BM-Ceta_20260623T100700157272.h5', 'camera_image_BM-Ceta_20260623T101422705399.h5', 'camera_image_BM-Ceta_20260623T101453695681.h5']
# {'host': '10.46.217.241',
#  'port': 9091,
#  'uri': 'http://10.46.217.241:9091',
#  'save_path': 'outputs/tiled_acquisitions',
#  'tiled_server': 'yes',
#  'tiled_server_status': 'running; serving path; files register manually',
#  'tiled_server_serving': 'outputs/tiled_acquisitions'}

# %% [markdown]
# ### Acquire a reference image

# %%
scan.dwell_time = 1e-6
scan.imsize = 512
scan.scan_region = [0, 0, 1, 1]

print("dwell_time :", scan.dwell_time)
print("image size :", scan.imsize)
print("scan region:", list(scan.scan_region))
# Out:
# dwell_time : 1e-06
# image size : 512
# scan region: [np.float64(0.0), np.float64(0.0), np.float64(1.0), np.float64(1.0)]

# %%
data_key = microscope.acquire_scanned_image(["haadf"])

image = client[data_key]["image"]["HAADF"].read()
metadata = dict(client[data_key]["image"]["HAADF"].metadata)

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(image, cmap="gray", interpolation="none")
ax.set_title(f"HAADF - dwell {scan.dwell_time * 1e6:.1f} us")
ax.axis("off")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Choose random beam positions

# %%
rng = np.random.default_rng(7)
n_points = 5
beam_points = rng.uniform(0.1, 0.9, size=(n_points, 2))

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(image, cmap="gray", interpolation="none")
height, width = image.shape
ax.scatter(beam_points[:, 0] * (width - 1), beam_points[:, 1] * (height - 1), c="tab:red", s=45)
for index, (x_frac, y_frac) in enumerate(beam_points, start=1):
    ax.text(x_frac * (width - 1), y_frac * (height - 1), str(index), color="white", ha="center", va="center")
ax.set_title("Random EDS beam positions")
ax.axis("off")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Place the beam and collect EDS spectra

# %%
spectra = []

for index, point in enumerate(beam_points, start=1):
    microscope.place_beam(point.tolist())
    key = microscope.acquire_spectrum("eds")
    node = client[key]["spectrum"]
    spectrum = np.squeeze(np.asarray(node.read()))
    metadata = dict(node.metadata)
    spectra.append({
        "point_index": index,
        "beam_position": point.tolist(),
        "tiled_key": key,
        "metadata": metadata,
        "spectrum": spectrum,
    })
    print(f"Point {index}: key={key}, beam={point.tolist()}, bins={spectrum.size}")
# Out:
# Point 1: key=spectrum_eds_20260624T102726373781.h5, beam=[0.6000763732837335, 0.8177710407756604], bins=4096
# Point 2: key=spectrum_eds_20260624T102728581060.h5, beam=[0.7205485521961549, 0.2801657519924735], bins=4096
# Point 3: key=spectrum_eds_20260624T102730767225.h5, beam=[0.34013302792898037, 0.7988427563170095], bins=4096
# Point 4: key=spectrum_eds_20260624T102732902423.h5, beam=[0.10421224365245979, 0.756982734706213], bins=4096
# Point 5: key=spectrum_eds_20260624T102735118880.h5, beam=[0.737655543001637, 0.47434796227497666], bins=4096

# %%
fig, ax = plt.subplots(figsize=(8, 4))
for record in spectra:
    ax.plot(record["spectrum"], label=f"Point {record['point_index']}")
ax.set_xlabel("Channel")
ax.set_ylabel("Counts")
ax.set_title("EDS spectra from random beam positions")
ax.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Configure and acquire an EDS spectrum

# %%
eds_proxy = tango.DeviceProxy("asyncroscopy/eds/default")
eds_proxy.exposure_time = 30  # in seconds

# %%
key = microscope.acquire_spectrum("eds")
node = client[key]["spectrum"]
spectrum = np.squeeze(np.asarray(node.read()))
metadata = dict(node.metadata)

print("Tiled key     :", key)
print("Metadata      :", metadata)
print("Spectrum shape:", spectrum.shape)
print("Spectrum dtype:", spectrum.dtype)
# Out:
# Tiled key     : spectrum_eds_20260624T102859182508.h5
# Metadata      : {'AccelerationVoltage': '200000', 'AcquisitionDatetime': '2026-06-24T14:28:59Z', 'AcquisitionStartDatetime': '2026-06-24T14:28:27Z', 'Alpha': '0.017422646', 'ApplicationSoftware': 'AutoScript TEM', 'ApplicationSoftwareVersion': '1.15.0.484', 'AzimuthAngle': '0.785398163', 'AzimuthAngle_140': '2.35619449', 'AzimuthAngle_156': '3.92699082', 'AzimuthAngle_172': '5.49778714', 'BeamConvergence': '0.0300023064', 'BeamDiameter': '0', 'Begin': '0', 'Begin_109': '0', 'Begin_117': '0.0728785469', 'Beta': '0.0426275879', 'C1LensIntensity': '-0.451996821', 'C2LensIntensity': '0.194393652', 'C3LensIntensity': '0.352058276', 'CameraLength': '0.091', 'CollectionAngle': '0.7', 'CollectionAngle_141': '0.7', 'CollectionAngle_157': '0.7', 'CollectionAngle_173': '0.7', 'ComputerName': 'TITAN52340180', 'ControlSoftwareVersion': '3.21.1', 'DarkGainCorrectionType': 'DarkGain', 'DarkGainCorrectionType_202': 'DarkGain', 'DarkGainCorrectionType_213': 'DarkGain', 'Defocus': '6.13379514e-07', 'Detector': 'SuperX', 'DetectorName': 'BF-S', 'DetectorName_103': 'DF-S', 'DetectorName_111': 'HAADF', 'DetectorName_119': 'SuperXG21', 'DetectorName_135': 'SuperXG22', 'DetectorName_151': 'SuperXG23', 'DetectorName_167': 'SuperXG24', 'DetectorName_183': 'BM-Ceta', 'DetectorName_193': 'EF-CCD', 'DetectorName_203': 'Flucam', 'DetectorType': 'ScanningDetector', 'DetectorType_104': 'ScanningDetector', 'DetectorType_112': 'ScanningDetector', 'DetectorType_120': 'AnalyticalDetector', 'DetectorType_136': 'AnalyticalDetector', 'DetectorType_152': 'AnalyticalDetector', 'DetectorType_168': 'AnalyticalDetector', 'DetectorType_184': 'ImagingDetector', 'DetectorType_194': 'ImagingDetector', 'DetectorType_204': 'ImagingDetector', 'Diameter': '0', 'Diameter_24': '7e-05', 'Diameter_30': '0.002', 'Diameter_36': '0', 'Diameter_42': '0', 'DiffractionLensIntensity': '0.191390786', 'Dispersion': '5', 'Dispersion_142': '5', 'Dispersion_158': '5', 'Dispersion_174': '5', 'EFTEMOn': 'false', 'ElectronicsNoise': '25.36', 'ElectronicsNoise_150': '25.17', 'ElectronicsNoise_166': '24.35', 'ElectronicsNoise_182': '25.46', 'ElevationAngle': '0.31415927', 'ElevationAngle_139': '0.31415927', 'ElevationAngle_155': '0.31415927', 'ElevationAngle_171': '0.31415927', 'Enabled': 'false', 'Enabled_106': 'false', 'Enabled_114': 'true', 'Enabled_122': 'true', 'Enabled_138': 'true', 'Enabled_154': 'true', 'Enabled_170': 'true', 'End': '0', 'End_110': '0', 'End_118': '0.2', 'ExposureTime': '1.28', 'ExposureTime_201': '0.001', 'ExposureTime_212': '0.0128', 'ExtractorVoltage': '3600.03662', 'Focus': '0.000613379514', 'FrameTime': '0.398883', 'Gain': '36.951', 'Gain_107': '21.75261', 'Gain_115': '25.2254206', 'Gain_205': '0.7', 'Guid': 'c0fbbad8-99fb-477b-86b1-9fc070bd35e9', 'GunLensSetting': '793.425751', 'Height': '1024', 'Height_200': '2048', 'Height_211': '512', 'HighMagnificationMode': 'None', 'HolderType': 'DoubleTilt', 'IlluminationIntensityNormalized': '0.194393652', 'IlluminationMode': 'Probe', 'Index': '0', 'Index_25': '1', 'Index_31': '0', 'Index_37': '0', 'Index_43': '0', 'InputCountRate': '728', 'InputCountRate_146': '589', 'InputCountRate_162': '601', 'InputCountRate_178': '763', 'Inserted': 'false', 'Inserted_105': 'false', 'Inserted_113': 'true', 'Inserted_121': 'true', 'Inserted_137': 'true', 'Inserted_153': 'true', 'Inserted_169': 'true', 'InstrumentClass': 'Titan', 'InstrumentID': '4018', 'InstrumentModel': 'Spectra', 'IntermediateLensIntensity': '0.0603362652', 'LastMeasuredScreenCurrent': '1.05305449e-10', 'LiveTime': '30.5130341', 'LiveTime_145': '30.5769256', 'LiveTime_161': '30.2465619', 'LiveTime_177': '30.4925634', 'LorentzLensIntensity': '0', 'MainsLockOn': 'false', 'Manufacturer': 'FEI Company', 'MechanismType': 'Motorized', 'MechanismType_22': 'Motorized', 'MechanismType_28': 'Motorized', 'MechanismType_34': 'Motorized', 'MechanismType_40': 'Motorized', 'MiniCondenserLensIntensity': '0.343435433', 'Name': 'C1', 'Name_21': 'C2', 'Name_27': 'C3', 'Name_33': 'OBJ', 'Nam ...
# Spectrum shape: (4096,)
# Spectrum dtype: uint32

# %%
plt.figure(figsize=(8, 4))
plt.plot(spectrum)
plt.xlabel("Channel")
plt.ylabel("Counts")
plt.title("EDS spectrum")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
metadata
# Out:
# {'AccelerationVoltage': '200000',
#  'AcquisitionDatetime': '2026-06-24T14:28:59Z',
#  'AcquisitionStartDatetime': '2026-06-24T14:28:27Z',
#  'Alpha': '0.017422646',
#  'ApplicationSoftware': 'AutoScript TEM',
#  'ApplicationSoftwareVersion': '1.15.0.484',
#  'AzimuthAngle': '0.785398163',
#  'AzimuthAngle_140': '2.35619449',
#  'AzimuthAngle_156': '3.92699082',
#  'AzimuthAngle_172': '5.49778714',
#  'BeamConvergence': '0.0300023064',
#  'BeamDiameter': '0',
#  'Begin': '0',
#  'Begin_109': '0',
#  'Begin_117': '0.0728785469',
#  'Beta': '0.0426275879',
#  'C1LensIntensity': '-0.451996821',
#  'C2LensIntensity': '0.194393652',
#  'C3LensIntensity': '0.352058276',
#  'CameraLength': '0.091',
#  'CollectionAngle': '0.7',
#  'CollectionAngle_141': '0.7',
#  'CollectionAngle_157': '0.7',
#  'CollectionAngle_173': '0.7',
#  'ComputerName': 'TITAN52340180',
#  'ControlSoftwareVersion': '3.21.1',
#  'DarkGainCorrectionType': 'DarkGain',
#  'DarkGainCorrectionType_202': 'DarkGain',
#  'DarkGainCorrectionType_213': 'DarkGain',
#  'Defocus': '6.13379514e-07',
#  'Detector': 'SuperX',
#  'DetectorName': 'BF-S',
#  'DetectorName_103': 'DF-S',
#  'DetectorName_111': 'HAADF',
#  'DetectorName_119': 'SuperXG21',
#  'DetectorName_135': 'SuperXG22',
#  'DetectorName_151': 'SuperXG23',
#  'DetectorName_167': 'SuperXG24',
#  'DetectorName_183': 'BM-Ceta',
#  'DetectorName_193': 'EF-CCD',
#  'DetectorName_203': 'Flucam',
#  'DetectorType': 'ScanningDetector',
#  'DetectorType_104': 'ScanningDetector',
#  'DetectorType_112': 'ScanningDetector',
#  'DetectorType_120': 'AnalyticalDetector',
#  'DetectorType_136': 'AnalyticalDetector',
#  'DetectorType_152': 'AnalyticalDetector',
#  'DetectorType_168': 'AnalyticalDetector',
#  'DetectorType_184': 'ImagingDetector',
#  'DetectorType_194': 'ImagingDetector',
#  'DetectorType_204': 'ImagingDetector',
#  'Diameter': '0',
#  'Diameter_24': '7e-05',
#  'Diameter_30': '0.002',
#  'Diameter_36': '0',
#  'Diameter_42': '0',
#  'DiffractionLensIntensity': '0.191390786',
#  'Dispersion': '5',
#  'Dispersion_142': '5',
#  'Dispersion_158': '5',
#  'Dispersion_174': '5',
#  'EFTEMOn': 'false',
#  'ElectronicsNoise': '25.36',
#  'ElectronicsNoise_150': '25.17',
#  'ElectronicsNoise_166': '24.35',
#  'ElectronicsNoise_182': '25.46',
#  'ElevationAngle': '0.31415927',
#  'ElevationAngle_139': '0.31415927',
#  'ElevationAngle_155': '0.31415927',
#  'ElevationAngle_171': '0.31415927',
#  'Enabled': 'false',
#  'Enabled_106': 'false',
#  'Enabled_114': 'true',
#  'Enabled_122': 'true',
#  'Enabled_138': 'true',
#  'Enabled_154': 'true',
#  'Enabled_170': 'true',
#  'End': '0',
#  'End_110': '0',
#  'End_118': '0.2',
#  'ExposureTime': '1.28',
#  'ExposureTime_201': '0.001',
#  'ExposureTime_212': '0.0128',
#  'ExtractorVoltage': '3600.03662',
#  'Focus': '0.000613379514',
#  'FrameTime': '0.398883',
#  'Gain': '36.951',
#  'Gain_107': '21.75261',
#  'Gain_115': '25.2254206',
#  'Gain_205': '0.7',
#  'Guid': 'c0fbbad8-99fb-477b-86b1-9fc070bd35e9',
#  'GunLensSetting': '793.425751',
#  'Height': '1024',
#  'Height_200': '2048',
#  'Height_211': '512',
#  'HighMagnificationMode': 'None',
#  'HolderType': 'DoubleTilt',
#  'IlluminationIntensityNormalized': '0.194393652',
#  'IlluminationMode': 'Probe',
#  'Index': '0',
#  'Index_25': '1',
#  'Index_31': '0',
#  'Index_37': '0',
#  'Index_43': '0',
#  'InputCountRate': '728',
#  'InputCountRate_146': '589',
#  'InputCountRate_162': '601',
#  'InputCountRate_178': '763',
#  'Inserted': 'false',
#  'Inserted_105': 'false',
#  'Inserted_113': 'true',
#  'Inserted_121': 'true',
#  'Inserted_137': 'true',
#  'Inserted_153': 'true',
#  'Inserted_169': 'true',
#  'InstrumentClass': 'Titan',
#  'InstrumentID': '4018',
#  'InstrumentModel': 'Spectra',
#  'IntermediateLensIntensity': '0.0603362652',
#  'LastMeasuredScreenCurrent': '1.05305449e-10',
#  'LiveTime': '30.5130341',
#  'LiveTime_145': '30.5769256',
#  'LiveTime_161': '30.2465619',
#  'LiveTime_177': '30.4925634',
#  'LorentzLensIntensity': '0',
#  'MainsLockOn': 'false',
#  'Manufacturer': 'FEI Company',
#  'MechanismType': 'Motorized',
#  'MechanismType_22': 'Motorized',
#  'MechanismType_28': 'Motorized',
#  'MechanismType_34': 'Motorized',
#  'MechanismType_40': 'Motorized',
#  'MiniCondenserLensIntensity': '0.343435433',
#  'Name': 'C1',
#  'Name_21': 'C2',
#  'Name_27': 'C3',
#  'Name_33': 'OBJ',
#  'Name_39': 'SA',
#  'NominalMagnification': '3620386.72',
#  'Number': '1',
#  'Number_20': '2',
#  'Number_26': '3',
#  'Number_32': '4',
#  'Number_38': '5',
#  'ObjectiveLensIntensity': '0.824263616',
#  'ObjectiveLensMode': 'HM',
#  'Offset': '0',
#  'OffsetEnergy': '-250',
#  'OffsetEnergy_149': '-250',
#  'OffsetEnergy_165': '-250',
#  'OffsetEnergy_181': '-250',
#  'Offset_108': '0',
#  'Offset_116': '-1.752',
#  'OperatingMode': 'STEM',
#  'OutputCountRate': '722',
#  'OutputCountRate_147': '584',
#  'OutputCountRate_163': '585',
#  'OutputCountRate_179': '755',
#  'ProbeMode': 'Nanoprobe',
#  'Projector1LensIntensity': '0.2809157',
#  'Projector2LensIntensity': '0.910340794',
#  'ProjectorMode': 'Diffraction',
#  'PulseProcessTime': '3e-06',
#  'PulseProcessTime_143': '3e-06',
#  'PulseProcessTime_159': '3e-06',
#  'PulseProcessTime_175': '3e-06',
#  'RealTime': '30.8565425',
#  'RealTime_144': '30.8563322',
#  'RealTime_160': '30.8561182',
#  'RealTime_176': '30.8558927',
#  'STEMFocus': '6.13379514e-07',
#  'SampleTiltCorrectionOn': 'false',
#  'ScanRotation': '0',
#  'ScreenCurrent': '1.05305449e-10',
#  'ShutterState': 'Opened',
#  'ShutterState_148': 'Opened',
#  'ShutterState_164': 'Opened',
#  'ShutterState_180': 'Opened',
#  'SourceType': 'XFEG',
#  'SpotIndex': '7',
#  'TEMOperatingSubMode': 'None',
#  'Type': 'None',
#  'Type_23': 'Cicular',
#  'Type_29': 'Cicular',
#  'Type_35': 'None',
#  'Type_41': 'None',
#  'VacuumMode': 'Ready',
#  'Width': '1024',
#  'Width_199': '2048',
#  'Width_210': '512',
#  'X': '2.31888908e-08',
#  'X_185': '2',
#  'X_187': '512',
#  'X_195': '1',
#  'X_197': '0',
#  'X_206': '1',
#  'X_208': '256',
#  'X_65': '4.05897982e-18',
#  'X_67': '0',
#  'X_69': '0',
#  'X_85': '-0.00026467242',
#  'Y': '2.31888908e-08',
#  'Y_186': '2',
#  'Y_188': '512',
#  'Y_196': '1',
#  'Y_198': '0',
#  'Y_207': '1',
#  'Y_209': '256',
#  'Y_66': '-6.81691992e-18',
#  'Y_68': '0',
#  'Y_70': '0',
#  'Y_86': '0.000124663776',
#  'Z': '-1.549161e-05',
#  'acquisition_type': 'spectrum',
#  'detector': 'eds'}
